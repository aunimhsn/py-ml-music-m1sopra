# %%
import pandas as pd
import sqldf

df = pd.read_csv('./data/vgsales.csv')

query_1 = """
SELECT *
FROM df
WHERE Platform = 'NES';
"""

df_view_1 = sqldf.run(query_1)
df_view_1
# Out:
#     index   Rank                                               Name Platform  \
# 0       1      2                                  Super Mario Bros.      NES
# 1       9     10                                          Duck Hunt      NES
# 2      22     23                                Super Mario Bros. 3      NES
# 3      96     97                                Super Mario Bros. 2      NES
# 4     127    128                                The Legend of Zelda      NES
# ..    ...    ...                                                ...      ...
# 93   5862   5864                                        Famista '91      NES
# 94   6161   6163                                        Famista '92      NES
# 95  10309  10311                               Final Fantasy I & II      NES
# 96  11985  11987  Teenage Mutant Ninja Turtles: Tournament Fighters      NES
# 97  12636  12638                                 Adventures of Lolo      NES
#
#       Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 0   1985.0      Platform                      Nintendo     29.08      3.58
# 1   1984.0       Shooter                      Nintendo     26.93      0.63
# 2   1988.0      Platform                      Nintendo      9.54      3.44
# 3   1988.0      Platform                      Nintendo      5.39      1.18
# 4   1986.0        Action                      Nintendo      3.74      0.93
# ..     ...           ...                           ...       ...       ...
# 93  1990.0        Sports            Namco Bandai Games      0.00      0.00
# 94  1991.0        Sports            Namco Bandai Games      0.00      0.00
# 95  1994.0  Role-Playing                        Square      0.00      0.00
# 96  1992.0      Fighting  Konami Digital Entertainment      0.04      0.01
# 97  1989.0        Puzzle                HAL Laboratory      0.06      0.00
#
#     JP_Sales  Other_Sales  Global_Sales
# 0       6.81         0.77         40.24
# 1       0.28         0.47         28.31
# 2       3.84         0.46         17.28
# 3       0.70         0.19          7.46
# 4       1.69         0.14          6.51
# ..       ...          ...           ...
# 93      0.30         0.00          0.30
# 94      0.28         0.00          0.28
# 95      0.11         0.00          0.11
# 96      0.02         0.00          0.07
# 97      0.00         0.00          0.06
#
# [98 rows x 12 columns]

# %%
query_2 = """
SELECT SUM(JP_Sales)
FROM df;
"""

df_view_2 = sqldf.run(query_2)
df_view_2

# %%
query_3 = """
SELECT COUNT(*)
FROM df
WHERE Year >= 2008;
"""

df_view_3 = sqldf.run(query_3)
df_view_3

# %%
query_4_1 = """
SELECT COUNT(*) AS nb_all_games
FROM df
"""
df_view_4_1 = sqldf.run(query_4_1)

query_4_2 = """
SELECT COUNT(*) AS nb_games_wii
FROM df
WHERE Platform = 'Wii'
"""
df_view_4_2 = sqldf.run(query_4_2)
(df_view_4_2['nb_games_wii'] / df_view_4_1['nb_all_games']) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 query_4_1 = """
#       2 SELECT COUNT(*) AS nb_all_games
#       3 FROM df
#       4 """
# ----> 5 df_view_4_1 = sqldf.run(query_4_1)
#       7 query_4_2 = """
#       8 SELECT COUNT(*) AS nb_games_wii
#       9 FROM df
#      10 WHERE Platform = 'Wii'
#      11 """
#      12 df_view_4_2 = sqldf.run(query_4_2)
#
# NameError: name 'sqldf' is not defined
